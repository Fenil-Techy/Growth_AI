# %%
import os
import traceback

# %%
from langchain_ollama import ChatOllama
from langchain.prompts import ChatPromptTemplate, HumanMessagePromptTemplate

# %%
llm=ChatOllama(model="llama3.1:8b")

# %%
TEMPLATE = """
You are an expert educational roadmap generator.

🎯 Your goal is to design a complete **week-wise roadmap** for learning `{context}` from scratch to an advanced level.

📅 Duration: {time_period}  
🎓 Learner’s Prior Knowledge: {learnings}  

---

🧠 **Instructions:**
- Build a practical, beginner-friendly roadmap.
- Skip or shorten any topics already known (see Prior Knowledge).
- Focus on what to learn each week – keep it clear and structured.
- Ensure smooth progression from basics to advanced.
- Do not assume prior deep knowledge unless specified.

✅ **Output Requirements:**
- Use structured Markdown format.
- Divide the roadmap into weeks (e.g., “Week 1”, “Week 2”, etc.).
- For each week:
  - Add a title for the focus of the week (e.g., “Python Basics”, “Web Scraping”).
  - Bullet-point the exact topics/concepts and subtopic/sub-concept to learn that week.
- Be concise, detailed
- Avoid unnecessary filler content and resources for now.

---

✍️ **Example Format:**

Week 1: Title
- Topic 1 :
  - Sub-topics 1


Begin the roadmap below:
"""

# %%
prompt=ChatPromptTemplate.from_messages([
    HumanMessagePromptTemplate.from_template(TEMPLATE)
])

# %%
context="python"
time_period="3-months"
learnings="nothing"

# %%
generator=prompt | llm

# %%
response=generator.invoke({"context":context,"time_period":time_period,"learnings":learnings})

# %%
roadmap=response.content

# %%
print(roadmap)
# Out:
# Here is a structured 3-month roadmap to learn Python from scratch to an advanced level:
#
# **Month 1: Python Basics (Weeks 1-4)**
#
# ### Week 1: Introduction to Python
# - What is Python?
#   - Brief history and evolution of Python
#   - Why use Python?
# - Setting up the environment:
#   - Installing Python on Windows, macOS, or Linux
#   - Choosing a code editor or IDE (e.g., PyCharm, Visual Studio Code)
# - Basic syntax and data types:
#   - Variables, data types, and type conversion
#   - Basic operators and control structures
#
# ### Week 2: Data Structures in Python
# - Lists:
#   - Creating and indexing lists
#   - List methods (append, extend, sort, etc.)
# - Tuples:
#   - Creating and indexing tuples
#   - Tuple methods
# - Sets:
#   - Creating and updating sets
#   - Set operations (union, intersection, difference)
# - Dictionaries:
#   - Creating and accessing dictionaries
#   - Dictionary methods (keys(), values(), items())
#
# ### Week 3: File Input/Output and Exception Handling
# - Reading and writing files:
#   - Text files (.txt) and CSV files (.csv)
#   - Binary files (.bin, .png, etc.)
# - Exception handling:
#   - Try-except blocks and error types (SyntaxError, ValueError, etc.)
#   - Raising custom exceptions
#
# ### Week 4: Functions and Modules in Python
# - Defining and calling functions:
#   - Function arguments and return values
#   - Lambda functions and anonymous functions
# - Importing modules:
#   - Built-in modules (math, random, time, etc.)
#   - Third-party libraries ( NumPy, pandas, requests, etc.)
#
# **Month 2: Data Analysis and Visualization with Python**
#
# ### Week 5: Introduction to Pandas and DataFrames
# - What is Pandas?
#   - History and evolution of Pandas
#   - Key features and benefits
# - Working with DataFrames:
#   - Creating and indexing DataFrames
#   - Selecting and filtering data
#
# ### Week 6: Data Manipulation with Pandas
# - Handling missing values:
#   - Dropping vs. filling missing values
#   - Filling missing values with mean, median, etc.
# - Merging and joining datasets:
#   - Inner joins, left joins, right joins, full outer joins
#
# ### Week 7: Data Visualization with Matplotlib and Seaborn
# - Introduction to data visualization:
#   - Importance of visualization in data analysis
#   - Choosing the right visualizations
# - Plotting with Matplotlib:
#   - Basic plots (line plots, scatter plots, etc.)
#   - Customizing plot appearance
#
# ### Week 8: Advanced Visualization with Seaborn and Plotly
# - Introduction to Seaborn:
#   - Using seaborn for visualization
#   - Creating informative and attractive visualizations
# - Introduction to Plotly:
#   - Interactive plots with hover text and zooming
#   - Creating dashboards with Plotly
#
# **Month 3: Advanced Topics in Python**
#
# ### Week 9: Web Scraping with BeautifulSoup and Requests
# - Introduction to web scraping:
#   - Importance of web scraping for data collection
#   - Choosing the right tools (BeautifulSoup, Scrapy, etc.)
# - Using BeautifulSoup:
#   - Parsing HTML and XML documents
#   - Finding and extracting specific data
#
# ### Week 10: Machine Learning Fundamentals with scikit-learn
# - Introduction to machine learning:
#   - Supervised vs. unsupervised learning
#   - Regression vs. classification problems
# - Working with datasets:
#   - Loading and preprocessing datasets
#   - Splitting data into training and testing sets
#
# ### Week 11: Advanced Topics in Machine Learning
# - Clustering algorithms:
#   - K-means clustering, hierarchical clustering, etc.
# - Dimensionality reduction techniques:
#   - PCA, t-SNE, feature selection, etc.
#
# ### Week 12: Project Development and Deployment
# - Building a real-world project:
#   - Choosing a problem to solve or a dataset to analyze
#   - Designing the project architecture and structure
# - Deploying the project:
#   - Using Flask or Django for web development
#   - Creating APIs with FastAPI or Pyramid
#
# This roadmap covers the basics of Python programming, data structures, file input/output, exception handling, functions, modules, Pandas, Matplotlib, Seaborn, Plotly, web scraping, and machine learning. It provides a structured plan to help learners progress from beginner to advanced level in 3 months.

# %%
roadmap_lines=roadmap.strip().split("\n")
weeks=[]
current_week=None
current_topics=[]

for line in roadmap_lines:
    line=line.strip()
    
    if line.startswith("###"):
        if current_week is not None:
            weeks.append({
                "week":current_week,
                "topics":current_topics
            })
        current_week=line.replace("###","").strip()
        current_topics=[]
    elif line.startswith("-"):
        topic = line[1:].strip()  # Remove the '-' and spaces
        current_topics.append(topic)
if current_week is not None:
    weeks.append({
        "week": current_week,
        "topics": current_topics
    })

for w in weeks:
    print(w["week"])
    for t in w["topics"]:
        print("  •", t)
# Out:
# 📅 **Month 1: Foundations**
# 📅 # 📅 Week 1: Python Basics
#   • Variables and Data Types (strings, numbers, booleans)
#   • Control Flow (if/else statements, for loops, while loops)
#   • Writing Functions in Python (function arguments, return types)
# 📅 # 📅 Week 2: Introduction to Modules and Packages
#   • Importing modules (math, random, etc.)
#   • Creating and using custom packages
#   • Understanding the `__init__.py` file
# 📅 # 📅 Week 3: Data Structures I - Lists and Tuples
#   • Creating and indexing lists and tuples
#   • List comprehensions for efficient data manipulation
#   • Common list methods (append, insert, remove)
# 📅 # 📅 Week 4: Data Structures II - Sets and Dictionaries
#   • Introduction to sets and dictionary data types
#   • Set operations (union, intersection, difference)
#   • Dictionary basics (creation, access, modification)
# 📅 **Month 2: Intermediate Topics**
# 📅 # 📅 Week 5: Object-Oriented Programming
#   • Classes and objects in Python
#   • Constructors (`__init__` method) and properties
#   • Inheritance and polymorphism
# 📅 # 📅 Week 6: File Input/Output and Persistence
#   • Reading and writing text files
#   • CSV, JSON, and pickle data formats
#   • Understanding file modes (r, w, a)
# 📅 # 📅 Week 7: Regular Expressions and Text Processing
#   • Introduction to regular expressions
#   • Pattern matching and substitution
#   • Using libraries like `re` for efficient text processing
# 📅 # 📅 Week 8: Debugging and Testing
#   • Basic debugging techniques (print statements, pdb)
#   • Unit testing with `unittest` module
#   • Writing effective test cases
# 📅 **Month 3: Advanced Topics**
# 📅 # 📅 Week 9: Web Scraping and APIs
#   • Introduction to web scraping using `requests` and `BeautifulSoup`
#   • API basics (GET, POST requests) and using libraries like `requests`
#   • Handling JSON responses
# 📅 # 📅 Week 10: Data Visualization and Analysis
#   • Introduction to data visualization with popular libraries like Matplotlib and Seaborn
#   • Creating plots and charts for different types of data
#   • Basic statistical analysis using Python
# 📅 # 📅 Week 11: Advanced Topics in Python
#   • Generator expressions and functions
#   • Context managers (`with` statement) and resource management
#   • Using `asyncio` for asynchronous programming
# 📅 # 📅 Week 12: Project Development and Review
#   • Applying learned concepts to a project of choice
#   • Best practices for code organization and readability
#   • Reviewing progress and setting goals for continued learning
